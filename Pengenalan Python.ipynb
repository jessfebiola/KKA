# %% [markdown]
# # Pengenalan Syntax Python
#
# **Kenapa Python di materi AI?**
# - Syntax-nya ringkas, gak perlu deklarasi tipe data, gak perlu `;` atau `{}`
# - Banyak library siap pakai (numpy, networkx, dll) yang bakal kepake di materi AI selanjutnya
# - Representasi struktur data seperti graph, tree, queue jauh lebih gampang ditulis

# %% [markdown]
# ## 1. Perbedaan Dasar Python vs C
#
# | | C | Python |
# |---|---|---|
# | Akhir statement | pakai `;` | gak perlu (baris baru = akhir statement) |
# | Blok kode | pakai `{ }` | pakai **indentasi** (wajib konsisten!) |
# | Deklarasi tipe | wajib (`int x = 5;`) | gak perlu, Python otomatis tau tipenya |
# | Kompilasi | perlu compile dulu (`gcc`) | langsung dijalankan (interpreted) |
# | Header | perlu `#include <stdio.h>` | tinggal `import` kalau perlu library |

# %%
# Contoh paling sederhana: cetak teks
# Di C: printf("Halo, dunia!\n");
print("Halo, dunia!")
# Out:
# Halo, dunia!

# %% [markdown]
# ## 2. Variabel & Tipe Data
#
# Di C kalian harus nulis `int x = 5;` atau `float y = 3.14;`. Di Python, tinggal langsung isi nilainya, tipe datanya otomatis mengikuti.

# %%
# Variabel di Python, gak perlu deklarasi tipe
x = 5           # int
y = 3.14         # float
nama = "Andi"    # string
is_lulus = True  # boolean (di C: pakai int 0/1 atau <stdbool.h>)

print(x, type(x))
print(y, type(y))
print(nama, type(nama))
print(is_lulus, type(is_lulus))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# Andi <class 'str'>
# True <class 'bool'>

# %% [markdown]
# ## 3. Operator
#
# Mirip C, cuma ada beberapa yang beda:
# - Pembagian: `/` selalu hasil float, `//` itu pembagian bulat (kayak `/` int di C), `%` tetap modulo
# - Pangkat: `**` (di C harus pakai `pow()` dari `math.h`)
# - Logika: `and`, `or`, `not` (bukan `&&`, `||`, `!`)

# %%
a = 7
b = 2

print("a / b  =", a / b)   # hasil float
print("a // b =", a // b)  # hasil int (floor division)
print("a % b  =", a % b)
print("a ** b =", a ** b)  # pangkat

print(True and False)
print(True or False)
print(not True)
# Out:
# a / b  = 3.5
# a // b = 3
# a % b  = 1
# a ** b = 49
# False
# True
# False

# %% [markdown]
# ## 4. Struktur Kontrol (if/else, loop)
#
# **Perhatikan:** gak ada `{ }`, gantinya pakai **titik dua `:`** lalu baris di bawahnya di-indent.

# %%
nilai = 85

if nilai >= 90:
    print("A")
elif nilai >= 80:
    print("B")
else:
    print("C")
# Out:
# B

# %%
# for loop - beda jauh sama C
# di C: for(int i = 0; i < 5; i++)
# di Python, pakai range()
for i in range(5):
    print("Iterasi ke-", i)
# Out:
# Iterasi ke- 0
# Iterasi ke- 1
# Iterasi ke- 2
# Iterasi ke- 3
# Iterasi ke- 4

# %%
# while loop, mirip konsepnya sama C
i = 0
while i < 5:
    print("i sekarang:", i)
    i += 1   # gak ada i++ di Python, jadi pakai i += 1
# Out:
# i sekarang: 0
# i sekarang: 1
# i sekarang: 2
# i sekarang: 3
# i sekarang: 4

# %% [markdown]
# ## 5. Struktur Data Bawaan Python
#
# Python punya struktur data siap pakai yang di C harus bikin manual (array dinamis, struct, dll).
#
# - **List** `[]` → mirip array tapi ukurannya fleksibel, isinya boleh campur tipe
# - **Tuple** `()` → mirip list tapi gak bisa diubah (immutable)
# - **Dictionary** `{key: value}` → mirip hash map / struct, tapi key-nya bebas
# - **Set** `{}` (tanpa key) → kumpulan data unik, gak ada duplikat

# %%
# List
angka = [3, 1, 4, 1, 5, 9]
angka.append(2)          # nambah elemen
print("List:", angka)
print("Elemen ke-0:", angka[0])
print("Panjang list:", len(angka))

# Tuple (gak bisa diubah)
titik = (3, 4)
print("Tuple:", titik)

# Dictionary, cocok buat representasi graph nanti!
mahasiswa = {"nama": "Budi", "nim": "5025231000", "semester": 3}
print("Dict:", mahasiswa)
print("Nama:", mahasiswa["nama"])

# Set
warna = {"merah", "biru", "merah", "hijau"}  # duplikat otomatis hilang
print("Set:", warna)
# Out:
# List: [3, 1, 4, 1, 5, 9, 2]
# Elemen ke-0: 3
# Panjang list: 7
# Tuple: (3, 4)
# Dict: {'nama': 'Budi', 'nim': '5025231000', 'semester': 3}
# Nama: Budi
# Set: {'hijau', 'merah', 'biru'}

# %% [markdown]
# ## 6. Fungsi
#
# Pakai keyword `def`, gak perlu deklarasi tipe return kayak di C.

# %%
def tambah(a, b):
    return a + b

def sapa(nama="Kawan"):   # bisa kasih default value, gak ada di C
    print(f"Halo, {nama}!")

print(tambah(3, 5))
sapa()
sapa("Mahasiswa IF")
# Out:
# 8
# Halo, Kawan!
# Halo, Mahasiswa IF!

# %% [markdown]
# ---
# ## 7. Representasi Graph di Python
#
# Cara paling umum dan gampang di Python: pakai **dictionary of list** (adjacency list).
#
# Setiap **key** = satu node, **value**-nya = list dari node-node tetangganya.

# %%
# Graph tak berarah (undirected) sederhana
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

for node, tetangga in graph.items():
    print(f"{node} -> {tetangga}")
# Out:
# A -> ['B', 'C']
# B -> ['A', 'D', 'E']
# C -> ['A', 'F']
# D -> ['B']
# E -> ['B', 'F']
# F -> ['C', 'E']

# %% [markdown]
# Kalau digambarkan, graph di atas kira-kira bentuknya begini:
#
# ```
#       A
#      / \
#     B   C
#    /|    \
#   D E     F
#      \   /
#       \ /
#        (E-F terhubung)
# ```

# %% [markdown]
# ## 8. BFS (Breadth-First Search)
#
# Jelajahi graph **level per level**, dari node awal ke tetangga-tetangganya dulu, baru ke tetangga dari tetangga, dst. Cocok buat cari **jalur terpendek** (dalam jumlah edge) di graph tanpa bobot.
#
# Queue (FIFO — First In First Out). Di Python kita pakai `collections.deque` biar operasi tambah/ambil di depan-belakang efisien (kalau pakai `list` biasa, `pop(0)` itu lambat / O(n)).

# %%
from collections import deque

def bfs(graph, start):
    visited = set()        # buat nyimpen node yang udah dikunjungi
    queue = deque([start])  # antrian, mulai dari node awal
    urutan_kunjungan = []

    visited.add(start)

    while queue:
        node = queue.popleft()   # ambil node paling depan (FIFO)
        urutan_kunjungan.append(node)

        for tetangga in graph[node]:
            if tetangga not in visited:
                visited.add(tetangga)   # tandai begitu dimasukkan ke queue
                queue.append(tetangga)

    return urutan_kunjungan

hasil_bfs = bfs(graph, 'A')
print("Urutan kunjungan BFS dari A:", hasil_bfs)
# Out:
# Urutan kunjungan BFS dari A: ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# **Cara kerja singkat, langkah demi langkah dari node A:**
# 1. Mulai dari `A`, masukkan ke queue → `queue = [A]`
# 2. Ambil `A`, kunjungi tetangganya `B, C` → masukkan ke queue → `queue = [B, C]`
# 3. Ambil `B`, kunjungi tetangganya yang belum dikunjungi `D, E` → `queue = [C, D, E]`
# 4. Ambil `C`, kunjungi tetangganya yang belum dikunjungi `F` → `queue = [D, E, F]`
# 5. Ambil `D`, gak ada tetangga baru
# 6. Ambil `E`, gak ada tetangga baru (F udah dikunjungi)
# 7. Ambil `F`, selesai
#
# Hasil: `A, B, C, D, E, F`

# %% [markdown]
# ## 9. DFS (Depth-First Search)
#
# Jelajahi graph **sedalam mungkin** dulu di satu cabang, baru balik (backtrack) kalau udah mentok. Cocok buat kasus kayak cek konektivitas, topological sort, atau eksplorasi state space di AI (misal solving puzzle).
#
# Ada 2 cara umum implementasi: **rekursif** (paling natural) dan **iteratif pakai stack (LIFO)**.

# %%
# DFS versi rekursif
def dfs_rekursif(graph, node, visited=None, urutan_kunjungan=None):
    if visited is None:
        visited = set()
        urutan_kunjungan = []

    visited.add(node)
    urutan_kunjungan.append(node)

    for tetangga in graph[node]:
        if tetangga not in visited:
            dfs_rekursif(graph, tetangga, visited, urutan_kunjungan)

    return urutan_kunjungan

hasil_dfs_rekursif = dfs_rekursif(graph, 'A')
print("Urutan kunjungan DFS (rekursif) dari A:", hasil_dfs_rekursif)
# Out:
# Urutan kunjungan DFS (rekursif) dari A: ['A', 'B', 'D', 'E', 'F', 'C']

# %%
# DFS versi iteratif, pakai stack manual (list biasa, karena append/pop di ujung itu O(1))
def dfs_iteratif(graph, start):
    visited = set()
    stack = [start]     # stack (LIFO)
    urutan_kunjungan = []

    while stack:
        node = stack.pop()   # ambil elemen paling atas/terakhir (LIFO)
        if node not in visited:
            visited.add(node)
            urutan_kunjungan.append(node)
            # masukkan tetangga dalam urutan terbalik biar urutan kunjungan
            # konsisten sama versi rekursif
            for tetangga in reversed(graph[node]):
                if tetangga not in visited:
                    stack.append(tetangga)

    return urutan_kunjungan

hasil_dfs_iteratif = dfs_iteratif(graph, 'A')
print("Urutan kunjungan DFS (iteratif) dari A:", hasil_dfs_iteratif)
# Out:
# Urutan kunjungan DFS (iteratif) dari A: ['A', 'B', 'D', 'E', 'F', 'C']

# %% [markdown]
# ## 10. Perbandingan BFS vs DFS
#
# | | BFS | DFS |
# |---|---|---|
# | Struktur data | Queue (FIFO) | Stack (LIFO) / rekursi |
# | Cara jelajah | Melebar per level | Menyelam sedalam mungkin dulu |
# | Cocok untuk | Jalur terpendek (unweighted graph) | Eksplorasi penuh, cek konektivitas, backtracking |
# | Kompleksitas | O(V + E) | O(V + E) |
#
# *(V = jumlah node/vertex, E = jumlah edge)*

# %% [markdown]
# ---
# ## 11. Sorting (Pengurutan) di Python
#
# Sorting itu salah satu algoritma paling dasar dan sering dipakai. Di Python ada cara instan pakai fungsi bawaan, tapi kita juga perlu paham cara kerja di baliknya (karena di soal ujian/tugas biasanya diminta implementasi manual, bukan tinggal panggil fungsi).

# %% [markdown]
# ### 11.1 Cara Instan: `sorted()` dan `.sort()`
#
# - `sorted(list)` → menghasilkan list baru yang sudah terurut, list aslinya gak berubah
# - `list.sort()` → mengurutkan list itu sendiri (in-place), gak menghasilkan list baru

# %%
angka = [5, 2, 9, 1, 5, 6]

# sorted() -> bikin list baru
hasil_sorted = sorted(angka)
print("List asli setelah sorted():", angka)
print("Hasil sorted():", hasil_sorted)

# .sort() -> ubah list aslinya langsung
angka.sort()
print("List asli setelah .sort():", angka)

# urutan menurun (descending), tinggal tambah reverse=True
print("Descending:", sorted(angka, reverse=True))
# Out:
# List asli setelah sorted(): [5, 2, 9, 1, 5, 6]
# Hasil sorted(): [1, 2, 5, 5, 6, 9]
# List asli setelah .sort(): [1, 2, 5, 5, 6, 9]
# Descending: [9, 6, 5, 5, 2, 1]

# %% [markdown]
# ### 11.2 Bubble Sort
#
# Bandingkan dua elemen bersebelahan, kalau urutannya salah, tukar posisinya. Ulangi terus sampai gak ada lagi yang perlu ditukar. Namanya "bubble" karena elemen terbesar "menggelembung" pelan-pelan ke ujung tiap kali satu putaran selesai.

# %%
def bubble_sort(arr):
    arr = arr.copy()  # biar list aslinya gak ikut berubah
    n = len(arr)

    for i in range(n):
        tertukar = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]  # tukar, gak perlu variabel temp kayak di C
                tertukar = True
        if not tertukar:   # kalau satu putaran gak ada pertukaran, berarti udah terurut, bisa berhenti lebih awal
            break

    return arr

data = [5, 2, 9, 1, 5, 6]
print("Sebelum:", data)
print("Sesudah bubble sort:", bubble_sort(data))
# Out:
# Sebelum: [5, 2, 9, 1, 5, 6]
# Sesudah bubble sort: [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ### 11.3 Selection Sort
#
# Di setiap putaran, cari elemen **terkecil** dari bagian yang belum terurut, lalu tukar ke posisi paling depan dari bagian yang belum terurut itu. Diulang sampai semua elemen kebagian posisi yang benar.

# %%
def selection_sort(arr):
    arr = arr.copy()
    n = len(arr)

    for i in range(n):
        idx_terkecil = i
        for j in range(i + 1, n):
            if arr[j] < arr[idx_terkecil]:
                idx_terkecil = j
        arr[i], arr[idx_terkecil] = arr[idx_terkecil], arr[i]  # tukar

    return arr

data = [5, 2, 9, 1, 5, 6]
print("Sebelum:", data)
print("Sesudah selection sort:", selection_sort(data))
# Out:
# Sebelum: [5, 2, 9, 1, 5, 6]
# Sesudah selection sort: [1, 2, 5, 5, 6, 9]

# %% [markdown]
# ### 11.4 Perbandingan Singkat
#
# | | Bubble Sort | Selection Sort |
# |---|---|---|
# | Ide dasar | Tukar elemen bersebelahan kalau salah urutan | Cari elemen terkecil, taruh di depan |
# | Kompleksitas | O(n²) | O(n²) |
# | Jumlah pertukaran (swap) | Bisa banyak | Maksimal n kali (lebih hemat swap) |
# | Best case | O(n) kalau udah terurut (ada optimasi `tertukar`) | Tetap O(n²), gak ada shortcut |

# %% [markdown]
# ## 12. Latihan
#
# ```python
# graph_latihan = {
#     1: [2, 3],
#     2: [1, 4],
#     3: [1, 4],
#     4: [2, 3, 5],
#     5: [4]
# }
# ```
#
# 1. Jalankan BFS dan DFS mulai dari node `1`, cetak hasil urutan kunjungannya
# 2. Modifikasi fungsi BFS di atas supaya bisa mengembalikan **jalur terpendek** dari node awal ke node tujuan tertentu (hint: simpan "parent" dari tiap node yang dikunjungi)
# 3. Coba tambahin 1 node baru ke `graph_latihan` yang gak terhubung sama sekali ke node lain, terus lihat apa yang terjadi kalau kalian DFS/BFS dari node `1` — apakah node baru itu ikut ke-visit?
# 4. Implementasikan **insertion sort** sendiri (belum dicontohin di atas), lalu bandingkan hasilnya sama `bubble_sort` dan `selection_sort` pakai data yang sama

# %%
# Ruang buat kalian coba-coba latihan di sini
graph_latihan = {
    1: [2, 3],
    2: [1, 4],
    3: [1, 4],
    4: [2, 3, 5],
    5: [4]
}

# tulis kode kalian di bawah ini
